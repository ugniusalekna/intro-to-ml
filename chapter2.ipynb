# %% [markdown]
# # Section 1

# %% [markdown]
# Some random shit in markup
#
# Imports blah blah blah

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Subsection about something

# %% [markdown]
# Some plot jada jada

# %%
x = np.linspace(-5, 5, 100)
y = x**2 + x + 1

fig, ax = plt.subplots(1, 1, figsize=(9, 6))
ax.plot(x, y)
ax.grid(True)

# %% [markdown]
# ## Some other subsection

# %% [markdown]
# Some other plot yadayada

# %%
x = np.linspace(-5, 5, 100)
y = np.exp(1)**(-x**2)

fig, ax = plt.subplots(1, 1, figsize=(9, 6))
ax.plot(x, y)
ax.grid(True)
